# %%
import pandas as pd
import matplotlib.pyplot as plt

# 读取csv文件
df = pd.read_csv('predictdata_with_year.csv')

# 计算每年的情绪预测值的平均值
df_mean = df.groupby('Year')['Sentiment'].mean().reset_index()

print(df_mean)

# 绘制每年的情绪预测值的平均值变化趋势的线图
import pandas as pd
import matplotlib.pyplot as plt

# 读入数据
data = pd.read_csv("predictdata_with_year.csv")

# 按年份计算平均情感极性
df_mean = data.groupby('Year')['Sentiment'].mean().reset_index()

# 设置颜色
color = '#FFBE7A'

# 绘制折线图
plt.plot(df_mean['Year'], df_mean['Sentiment'], color=color, linewidth=2.5)

# 设置背景填充
#plt.fill_between(df_mean['Year'], df_mean['Sentiment'], color=color, alpha=0.2)

# 设置网格线
plt.grid(color='white', linestyle='--')

# 设置图表标题、x轴标签、y轴标签
plt.title('Predicted Polarity Average Change Trend', fontweight='bold', fontsize=14)
plt.xlabel('Year', fontweight='bold', fontsize=12)
plt.ylabel('Predicted Polarity Average', fontweight='bold', fontsize=12)

# 设置图表背景颜色
plt.rcParams['axes.facecolor'] = '#F5F5F5'

plt.show()


# 标出每年的平均值标签
for index, row in df_mean.iterrows():
    plt.text(row['Year'], row['Sentiment'], str(round(row['Sentiment'], 2)), ha='center', va='bottom')

plt.show()
# Out:
#    Year  Sentiment
# 0  2017  -0.260504
# 1  2018  -0.190909
# 2  2019  -0.171569
# 3  2020  -0.215827
# 4  2021  -0.208738
# 5  2022  -0.373559
# 6  2023  -0.338818
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ...
